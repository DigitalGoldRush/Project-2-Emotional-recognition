# %% [markdown]
# <a href="https://colab.research.google.com/github/DigitalGoldRush/Project-2-Emotional-recognition/blob/main/streamlit_image_uploader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import model_from_json

# %%
with open('model.json') as f: 
  model_json=f.read()

loaded_model=model_from_json(model_json)

loaded_model.load_weights('model_weights.h5')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpg
image=mpg.imread('/content/Image-3.cv2')
plt.imshow(image)

# %%
image.shape
# Out:
# (396, 704, 3)

# %%
from PIL import Image
image = Image.open("/content/Image-3.cv2")
image = image.resize((150,150))
image.save(fp="image_reshaped.png")

# %%
image_reshaped=mpg.imread('image_reshaped.png')
plt.imshow(image_reshaped)

# %%
# pre-processing

image_reshaped=image_reshaped/255
image_reshaped.shape
# Out:
# (150, 150, 3)

# %%
import numpy as np
image_reshaped=np.expand_dims(image_reshaped, 0)

# %%
# Make some predictions with the loaded model
loaded_model.predict(image_reshaped)
# Out:
# array([[0.34006557, 0.04399226, 0.15168491, 0.07548651, 0.37709412,
#         0.01167668]], dtype=float32)

# %%
mapping={'Angry': 0, 'Fear': 1, 'Happy': 2, 'Neutral': 3, 'Sad': 4, 'Suprise': 5}

# %% [markdown]
# # Picture Prediction
#
# 0.37 = "Sad"
